# %%
from pcg_gazebo.parsers.sdf import create_sdf_element
import numpy as np

# %%
import os
import trimesh
import matplotlib.pyplot as plt
import numpy as np
from skimage.draw import random_shapes, disk
from skimage.util import invert
from pcg_gazebo.generators import HeightmapGenerator
from pcg_gazebo.generators.biomes import Biome, WhittakerBiome

# %%
# hg = HeightmapGenerator(
#     map_size=[400, 400, 1])

# hg.reset()
# hg.add_random_layer(min_value=0, max_value=0.2)
# hg.add_perlin_noise_layer(freq=300.0, octaves=10)
# hg.add_simplex_noise_layer(freq=300.0, octaves=10)
# hg.show()

# %%
# scene = trimesh.Scene([hg.heightmap.mesh.mesh])
# scene.show()

# %%
# # Creating a biome from flat colors
# biome = Biome(n_moisture_zones=1, n_elevation_zones=4)

# biome.add_biome('bottom', color=[125, 93, 33])
# biome.add_biome('middle1', color=[168, 154, 89])
# biome.add_biome('middle2', color=[127, 59, 11])
# biome.add_biome('top', color=[100, 133, 52])

# biome.add_rule(biome='bottom', moisture_zone=0, elevation_zone=0)
# biome.add_rule(biome='middle1', moisture_zone=0, elevation_zone=1)
# biome.add_rule(biome='middle2', moisture_zone=0, elevation_zone=2)
# biome.add_rule(biome='top', moisture_zone=0, elevation_zone=3)

# # The first blending of textures happends after the first layer ("bottom" biome)
# biome.set_min_height(height=0.75, elevation_zone=1)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=1)

# biome.set_min_height(height=0.85, elevation_zone=2)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=2)

# biome.set_min_height(height=0.95, elevation_zone=3)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=3)

# %%
# fig = biome.show()

# %%
# hg.biome = biome
# model_ground = hg.as_model()
# model_ground.name = 'pcg_test_heightmap'
# model_path = model_ground.to_gazebo_model(copy_resources=True, overwrite=True)

# print('Gazebo model stored at: {}'.format(model_path))

# print('List of files in {}: {}'.format(model_path, os.listdir(model_path)))
# print('List of files in {}: {}'.format(os.path.join(model_path, 'materials', 'textures'), os.listdir(os.path.join(model_path, 'materials', 'textures'))))

# %% [markdown]
# <!-- model_ground -->

# %%
# print(model_ground.to_sdf())

# %%
# print(hg.heightmap.to_sdf())

# %%
world = create_sdf_element('world')
state = create_sdf_element('state')
state.world_name="default"

# %%
# world.add_model('pcg_test_heightmap', model_ground)

# %%
# state.add_model('pcg_test_heightmap')

# state.models[-1].pose = [0,0,0,0,0,0]
# state.models[-1].add_link('link')
# state.models[-1].links[0].pose = [0,0,0,0,0,0]

# %%
# scale = np.random.uniform(0.8,1.2)
# mud_ground = create_sdf_element('model')
# mud_ground.static = True
# mud_ground.name = "mud_ground_{}".format(i)
# mud_ground.add_link(name="mud_ground_{}".format(i))
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# tree.links[0].self_collide = False
# tree.links[0].enable_wind = False
# tree.links[0].kinematic = False
# tree.links[0].add_visual("visual",visual)
# tree.links[0].add_collision("collision",collision)

# %%
world.add_include('include_1')
world.includes[0].uri = 'model://mud_box'

print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
# </world>

# %%
# mud_box = create_sdf_element('model')
# mud_box.static = True
# mud_box.name = "mud_box_{}".format(i)
# mud_box.add_link(name="mud_box_{}".format(i))
# scale = 10
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://mud_box"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://mud_box"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# asparagus.links[0].self_collide = False
# asparagus.links[0].enable_wind = False
# asparagus.links[0].kinematic = False
# asparagus.links[0].add_visual("visual",visual)
# asparagus.links[0].add_collision("collision",collision)
# world.add_model('mud_box_{}'.format(i), mud_box)

# %%
n_rows = 4
n_cols = 20
n_bushes = 3
n_trees = n_rows * n_cols * n_bushes
spacing = 3
bush_spacing = 12

# %%
cnt = 0
for row in range(int(-n_rows/2),int(n_rows/2)):
    for col in range(int(-n_cols/2),int(n_cols/2)):
        for bush in range(n_bushes):
            i = cnt
            yaw = np.random.uniform(0,np.pi*2)
            jitter_x = np.random.uniform(-0.5,0.5)
            jitter_y = np.random.uniform(-0.5,0.5)
            state.add_model('asparagus_{}'.format(i))
            state.models[i].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,0,0,yaw]
            state.models[i].add_link('link')
            state.models[i].links[0].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,0,0,yaw]
            cnt += 1

# %%
for i in range(n_trees):
    scale = 0.2
    scale_z = np.random.uniform(0.2,0.5)
    asparagus = create_sdf_element('model')
    asparagus.static = True
    asparagus.name = "asparagus_{}".format(i)
    asparagus.add_link(name="asparagus_{}".format(i))
    visual = create_sdf_element('visual')
    visual.geometry.mesh = create_sdf_element('mesh')
    visual.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    visual.geometry.mesh.scale=[scale, scale, scale_z]
    collision = create_sdf_element('collision')
    collision.geometry.mesh = create_sdf_element('mesh')
    collision.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    collision.geometry.mesh.scale = [scale, scale, scale_z]
    collision.max_contacts = 10
    asparagus.links[0].self_collide = False
    asparagus.links[0].enable_wind = False
    asparagus.links[0].kinematic = False
    asparagus.links[0].add_visual("visual",visual)
    asparagus.links[0].add_collision("collision",collision)
    world.add_model('asparagus_{}'.format(i), asparagus)

# %%
world.add_state("default",state)

# %%
print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
#   <model name="asparagus_0">
#     <static>1</static>
#     <link name="asparagus_0">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.567229</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.567229</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_1">
#     <static>1</static>
#     <link name="asparagus_1">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.607712</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.607712</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_2">
#     <static>1</static>
#     <link name="asparagus_2">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.566839</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.566839</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_3">
#     <static>1</static>
#     <link name="asparagus_3">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.545194</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.545194</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_4">
#     <static>1</static>
#     <link name="asparagus_4">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.642575</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.642575</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_5">
#     <static>1</static>
#     <link name="asparagus_5">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454279</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454279</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_6">
#     <static>1</static>
#     <link name="asparagus_6">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.42222</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.42222</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_7">
#     <static>1</static>
#     <link name="asparagus_7">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.587672</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.587672</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_8">
#     <static>1</static>
#     <link name="asparagus_8">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.448949</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.448949</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_9">
#     <static>1</static>
#     <link name="asparagus_9">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454235</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454235</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_10">
#     <static>1</static>
#     <link name="asparagus_10">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.451913</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.451913</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_11">
#     <static>1</static>
#     <link name="asparagus_11">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.424991</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.424991</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_12">
#     <static>1</static>
#     <link name="asparagus_12">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.449032</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.449032</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_13">
#     <static>1</static>
#     <link name="asparagus_13">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.433238</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.433238</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_14">
#     <static>1</static>
#     <link name="asparagus_14">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.420415</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.420415</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_15">
#     <static>1</static>
#     <link name="asparagus_15">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.53833</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.53833</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_16">
#     <static>1</static>
#     <link name="asparagus_16">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.50995</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.50995</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_17">
#     <static>1</static>
#     <link name="asparagus_17">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.444912</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.444912</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_18">
#     <static>1</static>
#     <link name="asparagus_18">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.689697</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.689697</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_19">
#     <static>1</static>
#     <link name="asparagus_19">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.478638</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.478638</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_20">
#     <static>1</static>
#     <link name="asparagus_20">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.691635</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.691635</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_21">
#     <static>1</static>
#     <link name="asparagus_21">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.486357</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.486357</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_22">
#     <static>1</static>
#     <link name="asparagus_22">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.556434</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.556434</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_23">
#     <static>1</static>
#     <link name="asparagus_23">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.477632</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.477632</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_24">
#     <static>1</static>
#     <link name="asparagus_24">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.672661</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.672661</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_25">
#     <static>1</static>
#     <link name="asparagus_25">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.621866</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.621866</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_26">
#     <static>1</static>
#     <link name="asparagus_26">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.519444</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.519444</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_27">
#     <static>1</static>
#     <link name="asparagus_27">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.557731</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.557731</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_28">
#     <static>1</static>
#     <link name="asparagus_28">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.532012</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.532012</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_29">
#     <static>1</static>
#     <link name="asparagus_29">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.422393</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.422393</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_30">
#     <static>1</static>
#     <link name="asparagus_30">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.623435</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.623435</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_31">
#     <static>1</static>
#     <link name="asparagus_31">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.457022</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.457022</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_32">
#     <static>1</static>
#     <link name="asparagus_32">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579231</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579231</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_33">
#     <static>1</static>
#     <link name="asparagus_33">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.671779</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.671779</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_34">
#     <static>1</static>
#     <link name="asparagus_34">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.661077</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.661077</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_35">
#     <static>1</static>
#     <link name="asparagus_35">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.542551</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.542551</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_36">
#     <static>1</static>
#     <link name="asparagus_36">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.475186</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.475186</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_37">
#     <static>1</static>
#     <link name="asparagus_37">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579642</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579642</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_38">
#     <static>1</static>
#     <link name="asparagus_38">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.438688</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.438688</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_39">
#     <static>1</static>
#     <link name="asparagus_39">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.425828</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.425828</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_40">
#     <static>1</static>
#     <link name="asparagus_40">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.688939</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.688939</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_41">
#     <static>1</static>
#     <link name="asparagus_41">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.696836</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.696836</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_42">
#     <static>1</static>
#     <link name="asparagus_42">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.480519</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.480519</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_43">
#     <static>1</static>
#     <link name="asparagus_43">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.540584</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.540584</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_44">
#     <static>1</static>
#     <link name="asparagus_44">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.432142</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.432142</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_45">
#     <static>1</static>
#     <link name="asparagus_45">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.487741</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.487741</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_46">
#     <static>1</static>
#     <link name="asparagus_46">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.660959</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.660959</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_47">
#     <static>1</static>
#     <link name="asparagus_47">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.443422</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.443422</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_48">
#     <static>1</static>
#     <link name="asparagus_48">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.536526</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.536526</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_49">
#     <static>1</static>
#     <link name="asparagus_49">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.481499</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.481499</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_50">
#     <static>1</static>
#     <link name="asparagus_50">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.624951</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.624951</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_51">
#     <static>1</static>
#     <link name="asparagus_51">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.530356</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.530356</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_52">
#     <static>1</static>
#     <link name="asparagus_52">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.597545</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.597545</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_53">
#     <static>1</static>
#     <link name="asparagus_53">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.463474</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.463474</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_54">
#     <static>1</static>
#     <link name="asparagus_54">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.480226</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.480226</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_55">
#     <static>1</static>
#     <link name="asparagus_55">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.559654</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.559654</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_56">
#     <static>1</static>
#     <link name="asparagus_56">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454572</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.454572</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_57">
#     <static>1</static>
#     <link name="asparagus_57">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.645668</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.645668</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_58">
#     <static>1</static>
#     <link name="asparagus_58">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579336</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.579336</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_59">
#     <static>1</static>
#     <link name="asparagus_59">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.413334</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.413334</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_60">
#     <static>1</static>
#     <link name="asparagus_60">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.564773</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.564773</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_61">
#     <static>1</static>
#     <link name="asparagus_61">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.578449</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.578449</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_62">
#     <static>1</static>
#     <link name="asparagus_62">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.401776</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.401776</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_63">
#     <static>1</static>
#     <link name="asparagus_63">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.696795</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.696795</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_64">
#     <static>1</static>
#     <link name="asparagus_64">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.560275</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.560275</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_65">
#     <static>1</static>
#     <link name="asparagus_65">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.556166</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.556166</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_66">
#     <static>1</static>
#     <link name="asparagus_66">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.588733</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.4 0.4 0.588733</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_67">
#     <static>1</static>
#     <link name="asparagus_67">
# ...
#       <pose frame="">-11.83 -33.3282 0 0 0 0.90696</pose>
#       <link name="link">
#         <pose frame="">-11.83 -33.3282 0 0 0 0.90696</pose>
#       </link>
#     </model>
#     <model name="asparagus_103">
#       <pose frame="">0.326876 -33.1046 0 0 0 0.327648</pose>
#       <link name="link">
#         <pose frame="">0.326876 -33.1046 0 0 0 0.327648</pose>
#       </link>
#     </model>
#     <model name="asparagus_104">
#       <pose frame="">12.1216 -32.5786 0 0 0 4.21082</pose>
#       <link name="link">
#         <pose frame="">12.1216 -32.5786 0 0 0 4.21082</pose>
#       </link>
#     </model>
#     <model name="asparagus_105">
#       <pose frame="">-11.6576 -29.5874 0 0 0 3.54929</pose>
#       <link name="link">
#         <pose frame="">-11.6576 -29.5874 0 0 0 3.54929</pose>
#       </link>
#     </model>
#     <model name="asparagus_106">
#       <pose frame="">0.137094 -29.833 0 0 0 3.23021</pose>
#       <link name="link">
#         <pose frame="">0.137094 -29.833 0 0 0 3.23021</pose>
#       </link>
#     </model>
#     <model name="asparagus_107">
#       <pose frame="">11.8433 -30.4371 0 0 0 3.83677</pose>
#       <link name="link">
#         <pose frame="">11.8433 -30.4371 0 0 0 3.83677</pose>
#       </link>
#     </model>
#     <model name="asparagus_108">
#       <pose frame="">-12.2158 -26.7075 0 0 0 4.06531</pose>
#       <link name="link">
#         <pose frame="">-12.2158 -26.7075 0 0 0 4.06531</pose>
#       </link>
#     </model>
#     <model name="asparagus_109">
#       <pose frame="">0.472927 -27.4537 0 0 0 3.1878</pose>
#       <link name="link">
#         <pose frame="">0.472927 -27.4537 0 0 0 3.1878</pose>
#       </link>
#     </model>
#     <model name="asparagus_110">
#       <pose frame="">12.1088 -27.3214 0 0 0 2.81143</pose>
#       <link name="link">
#         <pose frame="">12.1088 -27.3214 0 0 0 2.81143</pose>
#       </link>
#     </model>
#     <model name="asparagus_111">
#       <pose frame="">-11.5705 -24.05 0 0 0 5.18281</pose>
#       <link name="link">
#         <pose frame="">-11.5705 -24.05 0 0 0 5.18281</pose>
#       </link>
#     </model>
#     <model name="asparagus_112">
#       <pose frame="">-0.00153235 -24.3084 0 0 0 1.68797</pose>
#       <link name="link">
#         <pose frame="">-0.00153235 -24.3084 0 0 0 1.68797</pose>
#       </link>
#     </model>
#     <model name="asparagus_113">
#       <pose frame="">12.1834 -23.5141 0 0 0 3.65008</pose>
#       <link name="link">
#         <pose frame="">12.1834 -23.5141 0 0 0 3.65008</pose>
#       </link>
#     </model>
#     <model name="asparagus_114">
#       <pose frame="">-11.678 -21.1537 0 0 0 2.0681</pose>
#       <link name="link">
#         <pose frame="">-11.678 -21.1537 0 0 0 2.0681</pose>
#       </link>
#     </model>
#     <model name="asparagus_115">
#       <pose frame="">0.049248 -21.4305 0 0 0 1.4242</pose>
#       <link name="link">
#         <pose frame="">0.049248 -21.4305 0 0 0 1.4242</pose>
#       </link>
#     </model>
#     <model name="asparagus_116">
#       <pose frame="">11.786 -21.3516 0 0 0 3.70463</pose>
#       <link name="link">
#         <pose frame="">11.786 -21.3516 0 0 0 3.70463</pose>
#       </link>
#     </model>
#     <model name="asparagus_117">
#       <pose frame="">-12.3875 -17.7717 0 0 0 6.1552</pose>
#       <link name="link">
#         <pose frame="">-12.3875 -17.7717 0 0 0 6.1552</pose>
#       </link>
#     </model>
#     <model name="asparagus_118">
#       <pose frame="">0.199072 -18.0707 0 0 0 3.13282</pose>
#       <link name="link">
#         <pose frame="">0.199072 -18.0707 0 0 0 3.13282</pose>
#       </link>
#     </model>
#     <model name="asparagus_119">
#       <pose frame="">11.6576 -17.5436 0 0 0 1.84189</pose>
#       <link name="link">
#         <pose frame="">11.6576 -17.5436 0 0 0 1.84189</pose>
#       </link>
#     </model>
#     <model name="asparagus_120">
#       <pose frame="">-11.9062 -14.6186 0 0 0 1.9688</pose>
#       <link name="link">
#         <pose frame="">-11.9062 -14.6186 0 0 0 1.9688</pose>
#       </link>
#     </model>
#     <model name="asparagus_121">
#       <pose frame="">-0.109463 -14.64 0 0 0 4.39831</pose>
#       <link name="link">
#         <pose frame="">-0.109463 -14.64 0 0 0 4.39831</pose>
#       </link>
#     </model>
#     <model name="asparagus_122">
#       <pose frame="">11.5143 -14.6999 0 0 0 1.81008</pose>
#       <link name="link">
#         <pose frame="">11.5143 -14.6999 0 0 0 1.81008</pose>
#       </link>
#     </model>
#     <model name="asparagus_123">
#       <pose frame="">-12.3768 -11.6789 0 0 0 3.03129</pose>
#       <link name="link">
#         <pose frame="">-12.3768 -11.6789 0 0 0 3.03129</pose>
#       </link>
#     </model>
#     <model name="asparagus_124">
#       <pose frame="">0.168718 -11.7592 0 0 0 5.06</pose>
#       <link name="link">
#         <pose frame="">0.168718 -11.7592 0 0 0 5.06</pose>
#       </link>
#     </model>
#     <model name="asparagus_125">
#       <pose frame="">11.9892 -12.1926 0 0 0 0.607869</pose>
#       <link name="link">
#         <pose frame="">11.9892 -12.1926 0 0 0 0.607869</pose>
#       </link>
#     </model>
#     <model name="asparagus_126">
#       <pose frame="">-12.4056 -8.72448 0 0 0 5.31805</pose>
#       <link name="link">
#         <pose frame="">-12.4056 -8.72448 0 0 0 5.31805</pose>
#       </link>
#     </model>
#     <model name="asparagus_127">
#       <pose frame="">-0.215999 -9.18984 0 0 0 1.39248</pose>
#       <link name="link">
#         <pose frame="">-0.215999 -9.18984 0 0 0 1.39248</pose>
#       </link>
#     </model>
#     <model name="asparagus_128">
#       <pose frame="">12.2661 -8.95558 0 0 0 3.0297</pose>
#       <link name="link">
#         <pose frame="">12.2661 -8.95558 0 0 0 3.0297</pose>
#       </link>
#     </model>
#     <model name="asparagus_129">
#       <pose frame="">-12.3929 -5.9105 0 0 0 5.71611</pose>
#       <link name="link">
#         <pose frame="">-12.3929 -5.9105 0 0 0 5.71611</pose>
#       </link>
#     </model>
#     <model name="asparagus_130">
#       <pose frame="">0.348958 -5.78583 0 0 0 6.21616</pose>
#       <link name="link">
#         <pose frame="">0.348958 -5.78583 0 0 0 6.21616</pose>
#       </link>
#     </model>
#     <model name="asparagus_131">
#       <pose frame="">11.75 -5.62596 0 0 0 5.60984</pose>
#       <link name="link">
#         <pose frame="">11.75 -5.62596 0 0 0 5.60984</pose>
#       </link>
#     </model>
#     <model name="asparagus_132">
#       <pose frame="">-12.0311 -3.09401 0 0 0 2.85967</pose>
#       <link name="link">
#         <pose frame="">-12.0311 -3.09401 0 0 0 2.85967</pose>
#       </link>
#     </model>
#     <model name="asparagus_133">
#       <pose frame="">-0.230185 -2.58121 0 0 0 3.66313</pose>
#       <link name="link">
#         <pose frame="">-0.230185 -2.58121 0 0 0 3.66313</pose>
#       </link>
#     </model>
#     <model name="asparagus_134">
#       <pose frame="">11.636 -2.58021 0 0 0 3.77198</pose>
#       <link name="link">
#         <pose frame="">11.636 -2.58021 0 0 0 3.77198</pose>
#       </link>
#     </model>
#     <model name="asparagus_135">
#       <pose frame="">-11.9695 -0.210588 0 0 0 1.59112</pose>
#       <link name="link">
#         <pose frame="">-11.9695 -0.210588 0 0 0 1.59112</pose>
#       </link>
#     </model>
#     <model name="asparagus_136">
#       <pose frame="">-0.363729 0.164104 0 0 0 6.12661</pose>
#       <link name="link">
#         <pose frame="">-0.363729 0.164104 0 0 0 6.12661</pose>
#       </link>
#     </model>
#     <model name="asparagus_137">
#       <pose frame="">12.1558 -0.274204 0 0 0 0.972511</pose>
#       <link name="link">
#         <pose frame="">12.1558 -0.274204 0 0 0 0.972511</pose>
#       </link>
#     </model>
#     <model name="asparagus_138">
#       <pose frame="">-12.2693 2.9354 0 0 0 4.39704</pose>
#       <link name="link">
#         <pose frame="">-12.2693 2.9354 0 0 0 4.39704</pose>
#       </link>
#     </model>
#     <model name="asparagus_139">
#       <pose frame="">0.23512 2.95477 0 0 0 0.99195</pose>
#       <link name="link">
#         <pose frame="">0.23512 2.95477 0 0 0 0.99195</pose>
#       </link>
#     </model>
#     <model name="asparagus_140">
#       <pose frame="">12.1626 3.20804 0 0 0 0.949413</pose>
#       <link name="link">
#         <pose frame="">12.1626 3.20804 0 0 0 0.949413</pose>
#       </link>
#     </model>
#     <model name="asparagus_141">
#       <pose frame="">-11.8922 5.98821 0 0 0 5.04429</pose>
#       <link name="link">
#         <pose frame="">-11.8922 5.98821 0 0 0 5.04429</pose>
#       </link>
#     </model>
#     <model name="asparagus_142">
#       <pose frame="">-0.404791 6.42254 0 0 0 5.1172</pose>
#       <link name="link">
#         <pose frame="">-0.404791 6.42254 0 0 0 5.1172</pose>
#       </link>
#     </model>
#     <model name="asparagus_143">
#       <pose frame="">12.3277 5.89925 0 0 0 4.01917</pose>
#       <link name="link">
#         <pose frame="">12.3277 5.89925 0 0 0 4.01917</pose>
#       </link>
#     </model>
#     <model name="asparagus_144">
#       <pose frame="">-12.2115 9.19596 0 0 0 5.68124</pose>
#       <link name="link">
#         <pose frame="">-12.2115 9.19596 0 0 0 5.68124</pose>
#       </link>
#     </model>
#     <model name="asparagus_145">
#       <pose frame="">0.147528 8.98376 0 0 0 3.73955</pose>
#       <link name="link">
#         <pose frame="">0.147528 8.98376 0 0 0 3.73955</pose>
#       </link>
#     </model>
#     <model name="asparagus_146">
#       <pose frame="">11.8783 8.56332 0 0 0 3.23712</pose>
#       <link name="link">
#         <pose frame="">11.8783 8.56332 0 0 0 3.23712</pose>
#       </link>
#     </model>
#     <model name="asparagus_147">
#       <pose frame="">-12.065 12.0574 0 0 0 0.0699249</pose>
#       <link name="link">
#         <pose frame="">-12.065 12.0574 0 0 0 0.0699249</pose>
#       </link>
#     </model>
#     <model name="asparagus_148">
#       <pose frame="">-0.194961 12.0663 0 0 0 3.20293</pose>
#       <link name="link">
#         <pose frame="">-0.194961 12.0663 0 0 0 3.20293</pose>
#       </link>
#     </model>
#     <model name="asparagus_149">
#       <pose frame="">12.3673 11.6278 0 0 0 3.16125</pose>
#       <link name="link">
#         <pose frame="">12.3673 11.6278 0 0 0 3.16125</pose>
#       </link>
#     </model>
#     <model name="asparagus_150">
#       <pose frame="">-11.7478 14.8001 0 0 0 2.26105</pose>
#       <link name="link">
#         <pose frame="">-11.7478 14.8001 0 0 0 2.26105</pose>
#       </link>
#     </model>
#     <model name="asparagus_151">
#       <pose frame="">-0.45202 15.3368 0 0 0 0.130847</pose>
#       <link name="link">
#         <pose frame="">-0.45202 15.3368 0 0 0 0.130847</pose>
#       </link>
#     </model>
#     <model name="asparagus_152">
#       <pose frame="">12.0607 14.985 0 0 0 0.746065</pose>
#       <link name="link">
#         <pose frame="">12.0607 14.985 0 0 0 0.746065</pose>
#       </link>
#     </model>
#     <model name="asparagus_153">
#       <pose frame="">-12.2329 17.8346 0 0 0 0.233249</pose>
#       <link name="link">
#         <pose frame="">-12.2329 17.8346 0 0 0 0.233249</pose>
#       </link>
#     </model>
#     <model name="asparagus_154">
#       <pose frame="">-0.492037 18.2204 0 0 0 3.42351</pose>
#       <link name="link">
#         <pose frame="">-0.492037 18.2204 0 0 0 3.42351</pose>
#       </link>
#     </model>
#     <model name="asparagus_155">
#       <pose frame="">12.0375 17.9388 0 0 0 4.80462</pose>
#       <link name="link">
#         <pose frame="">12.0375 17.9388 0 0 0 4.80462</pose>
#       </link>
#     </model>
#     <model name="asparagus_156">
#       <pose frame="">-12.3704 21.0411 0 0 0 5.67084</pose>
#       <link name="link">
#         <pose frame="">-12.3704 21.0411 0 0 0 5.67084</pose>
#       </link>
#     </model>
#     <model name="asparagus_157">
#       <pose frame="">0.0244586 21.2386 0 0 0 5.82656</pose>
#       <link name="link">
#         <pose frame="">0.0244586 21.2386 0 0 0 5.82656</pose>
#       </link>
#     </model>
#     <model name="asparagus_158">
#       <pose frame="">11.8947 21.1416 0 0 0 1.88948</pose>
#       <link name="link">
#         <pose frame="">11.8947 21.1416 0 0 0 1.88948</pose>
#       </link>
#     </model>
#     <model name="asparagus_159">
#       <pose frame="">-12.1712 24.3083 0 0 0 3.86767</pose>
#       <link name="link">
#         <pose frame="">-12.1712 24.3083 0 0 0 3.86767</pose>
#       </link>
#     </model>
#     <model name="asparagus_160">
#       <pose frame="">-0.125947 24.4576 0 0 0 0.997757</pose>
#       <link name="link">
#         <pose frame="">-0.125947 24.4576 0 0 0 0.997757</pose>
#       </link>
#     </model>
#     <model name="asparagus_161">
#       <pose frame="">11.5806 24.2601 0 0 0 3.30676</pose>
#       <link name="link">
#         <pose frame="">11.5806 24.2601 0 0 0 3.30676</pose>
#       </link>
#     </model>
#     <model name="asparagus_162">
#       <pose frame="">-12.4315 27.3518 0 0 0 5.97161</pose>
#       <link name="link">
#         <pose frame="">-12.4315 27.3518 0 0 0 5.97161</pose>
#       </link>
#     </model>
#     <model name="asparagus_163">
#       <pose frame="">-0.0209093 27.4077 0 0 0 1.67178</pose>
#       <link name="link">
#         <pose frame="">-0.0209093 27.4077 0 0 0 1.67178</pose>
#       </link>
#     </model>
#     <model name="asparagus_164">
#       <pose frame="">12.1128 26.7056 0 0 0 3.70115</pose>
#       <link name="link">
#         <pose frame="">12.1128 26.7056 0 0 0 3.70115</pose>
#       </link>
#     </model>
#     <model name="asparagus_165">
#       <pose frame="">-12.366 29.933 0 0 0 2.42149</pose>
#       <link name="link">
#         <pose frame="">-12.366 29.933 0 0 0 2.42149</pose>
#       </link>
#     </model>
#     <model name="asparagus_166">
#       <pose frame="">0.30201 29.8412 0 0 0 3.27007</pose>
#       <link name="link">
#         <pose frame="">0.30201 29.8412 0 0 0 3.27007</pose>
#       </link>
#     </model>
#     <model name="asparagus_167">
#       <pose frame="">12.431 29.5281 0 0 0 5.1401</pose>
#       <link name="link">
#         <pose frame="">12.431 29.5281 0 0 0 5.1401</pose>
#       </link>
#     </model>
#     <model name="asparagus_168">
#       <pose frame="">-12.1766 32.5975 0 0 0 5.16653</pose>
#       <link name="link">
#         <pose frame="">-12.1766 32.5975 0 0 0 5.16653</pose>
#       </link>
#     </model>
#     <model name="asparagus_169">
#       <pose frame="">0.0743028 32.7046 0 0 0 6.14176</pose>
#       <link name="link">
#         <pose frame="">0.0743028 32.7046 0 0 0 6.14176</pose>
#       </link>
#     </model>
#     <model name="asparagus_170">
#       <pose frame="">12.2707 32.5211 0 0 0 5.27504</pose>
#       <link name="link">
#         <pose frame="">12.2707 32.5211 0 0 0 5.27504</pose>
#       </link>
#     </model>
#     <model name="asparagus_171">
#       <pose frame="">-11.6168 36.1204 0 0 0 0.539829</pose>
#       <link name="link">
#         <pose frame="">-11.6168 36.1204 0 0 0 0.539829</pose>
#       </link>
#     </model>
#     <model name="asparagus_172">
#       <pose frame="">-0.377321 36.1888 0 0 0 1.87011</pose>
#       <link name="link">
#         <pose frame="">-0.377321 36.1888 0 0 0 1.87011</pose>
#       </link>
#     </model>
#     <model name="asparagus_173">
#       <pose frame="">12.4533 36.0604 0 0 0 3.36391</pose>
#       <link name="link">
#         <pose frame="">12.4533 36.0604 0 0 0 3.36391</pose>
#       </link>
#     </model>
#     <model name="asparagus_174">
#       <pose frame="">-12.0591 38.5339 0 0 0 4.05348</pose>
#       <link name="link">
#         <pose frame="">-12.0591 38.5339 0 0 0 4.05348</pose>
#       </link>
#     </model>
#     <model name="asparagus_175">
#       <pose frame="">0.235921 38.5149 0 0 0 2.03247</pose>
#       <link name="link">
#         <pose frame="">0.235921 38.5149 0 0 0 2.03247</pose>
#       </link>
#     </model>
#     <model name="asparagus_176">
#       <pose frame="">11.5858 38.6694 0 0 0 1.78991</pose>
#       <link name="link">
#         <pose frame="">11.5858 38.6694 0 0 0 1.78991</pose>
#       </link>
#     </model>
#     <model name="asparagus_177">
#       <pose frame="">-12.1974 42.376 0 0 0 0.490575</pose>
#       <link name="link">
#         <pose frame="">-12.1974 42.376 0 0 0 0.490575</pose>
#       </link>
#     </model>
#     <model name="asparagus_178">
#       <pose frame="">0.279189 42.2478 0 0 0 5.92446</pose>
#       <link name="link">
#         <pose frame="">0.279189 42.2478 0 0 0 5.92446</pose>
#       </link>
#     </model>
#     <model name="asparagus_179">
#       <pose frame="">11.5581 42.1992 0 0 0 5.0877</pose>
#       <link name="link">
#         <pose frame="">11.5581 42.1992 0 0 0 5.0877</pose>
#       </link>
#     </model>
#   </state>
# </world>

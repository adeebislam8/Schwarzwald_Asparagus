# %%
from pcg_gazebo.parsers.sdf import create_sdf_element
import numpy as np

# %%
import os
import trimesh
import matplotlib.pyplot as plt
import numpy as np
from skimage.draw import random_shapes, disk
from skimage.util import invert
from pcg_gazebo.generators import HeightmapGenerator
from pcg_gazebo.generators.biomes import Biome, WhittakerBiome

# %%
# hg = HeightmapGenerator(
#     map_size=[400, 400, 1])

# hg.reset()
# hg.add_random_layer(min_value=0, max_value=0.2)
# hg.add_perlin_noise_layer(freq=300.0, octaves=10)
# hg.add_simplex_noise_layer(freq=300.0, octaves=10)
# hg.show()

# %%
# scene = trimesh.Scene([hg.heightmap.mesh.mesh])
# scene.show()

# %%
# # Creating a biome from flat colors
# biome = Biome(n_moisture_zones=1, n_elevation_zones=4)

# biome.add_biome('bottom', color=[125, 93, 33])
# biome.add_biome('middle1', color=[168, 154, 89])
# biome.add_biome('middle2', color=[127, 59, 11])
# biome.add_biome('top', color=[100, 133, 52])

# biome.add_rule(biome='bottom', moisture_zone=0, elevation_zone=0)
# biome.add_rule(biome='middle1', moisture_zone=0, elevation_zone=1)
# biome.add_rule(biome='middle2', moisture_zone=0, elevation_zone=2)
# biome.add_rule(biome='top', moisture_zone=0, elevation_zone=3)

# # The first blending of textures happends after the first layer ("bottom" biome)
# biome.set_min_height(height=0.75, elevation_zone=1)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=1)

# biome.set_min_height(height=0.85, elevation_zone=2)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=2)

# biome.set_min_height(height=0.95, elevation_zone=3)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=3)

# %%
# fig = biome.show()

# %%
# hg.biome = biome
# model_ground = hg.as_model()
# model_ground.name = 'pcg_test_heightmap'
# model_path = model_ground.to_gazebo_model(copy_resources=True, overwrite=True)

# print('Gazebo model stored at: {}'.format(model_path))

# print('List of files in {}: {}'.format(model_path, os.listdir(model_path)))
# print('List of files in {}: {}'.format(os.path.join(model_path, 'materials', 'textures'), os.listdir(os.path.join(model_path, 'materials', 'textures'))))

# %% [markdown]
# <!-- model_ground -->

# %%
# print(model_ground.to_sdf())

# %%
# print(hg.heightmap.to_sdf())

# %%
world = create_sdf_element('world')
state = create_sdf_element('state')
state.world_name="default"

# %%
# world.add_model('pcg_test_heightmap', model_ground)

# %%
# state.add_model('pcg_test_heightmap')

# state.models[-1].pose = [0,0,0,0,0,0]
# state.models[-1].add_link('link')
# state.models[-1].links[0].pose = [0,0,0,0,0,0]

# %%
# scale = np.random.uniform(0.8,1.2)
# mud_ground = create_sdf_element('model')
# mud_ground.static = True
# mud_ground.name = "mud_ground_{}".format(i)
# mud_ground.add_link(name="mud_ground_{}".format(i))
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# tree.links[0].self_collide = False
# tree.links[0].enable_wind = False
# tree.links[0].kinematic = False
# tree.links[0].add_visual("visual",visual)
# tree.links[0].add_collision("collision",collision)

# %%
world.add_include('include_1')
world.includes[0].uri = 'model://mud_box'

print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
# </world>

# %%
world.add_include('include_2')
world.includes[1].uri = 'model://sun'

print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
#   <include>
#     <uri>model://sun</uri>
#   </include>
# </world>

# %%
# mud_box = create_sdf_element('model')
# mud_box.static = True
# mud_box.name = "mud_box_{}".format(i)
# mud_box.add_link(name="mud_box_{}".format(i))
# scale = 10
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://mud_box"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://mud_box"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# asparagus.links[0].self_collide = False
# asparagus.links[0].enable_wind = False
# asparagus.links[0].kinematic = False
# asparagus.links[0].add_visual("visual",visual)
# asparagus.links[0].add_collision("collision",collision)
# world.add_model('mud_box_{}'.format(i), mud_box)

# %%
n_rows = 3
n_cols = 10
n_bushes = 3
n_trees = n_rows * n_cols * n_bushes
spacing = 0.75
bush_spacing = 3.75

# %%
cnt = 0
for row in range(int(-n_rows/2),int(n_rows/2)):
    for col in range(int(-n_cols/2),int(n_cols/2)):
        for bush in range(n_bushes):
            i = cnt
            roll = np.random.normal(0,0.1)
            pitch = np.random.normal(0,0.1)
            yaw = np.random.uniform(0,np.pi*2)
            jitter_x = np.random.uniform(-0.15,0.15)
            jitter_y = np.random.uniform(-0.15,0.15)
            state.add_model('asparagus_{}'.format(i))
            state.models[i].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,roll,pitch,yaw]
            state.models[i].add_link('link')
            state.models[i].links[0].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,roll,pitch,yaw]
            cnt += 1

# %%
for i in range(n_trees):
    scale = 0.08
    #scale_z = np.random.uniform(0.0125,0.15)
    scale_z = np.random.normal(0.08,0.015)
    asparagus = create_sdf_element('model')
    asparagus.static = True
    asparagus.name = "asparagus_{}".format(i)
    asparagus.add_link(name="asparagus_{}".format(i))
    visual = create_sdf_element('visual')
    visual.geometry.mesh = create_sdf_element('mesh')
    visual.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    visual.geometry.mesh.scale=[scale, scale, scale_z]
    collision = create_sdf_element('collision')
    collision.geometry.mesh = create_sdf_element('mesh')
    collision.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    collision.geometry.mesh.scale = [scale, scale, scale_z]
    collision.max_contacts = 10
    asparagus.links[0].self_collide = False
    asparagus.links[0].enable_wind = False
    asparagus.links[0].kinematic = False
    asparagus.links[0].add_visual("visual",visual)
    asparagus.links[0].add_collision("collision",collision)
    world.add_model('asparagus_{}'.format(i), asparagus)

# %%
world.add_state("default",state)

# %%
print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
#   <include>
#     <uri>model://sun</uri>
#   </include>
#   <model name="asparagus_0">
#     <static>1</static>
#     <link name="asparagus_0">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.105827</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.105827</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_1">
#     <static>1</static>
#     <link name="asparagus_1">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0600329</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0600329</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_2">
#     <static>1</static>
#     <link name="asparagus_2">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.116116</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.116116</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_3">
#     <static>1</static>
#     <link name="asparagus_3">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.108466</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.108466</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_4">
#     <static>1</static>
#     <link name="asparagus_4">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.07142</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.07142</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_5">
#     <static>1</static>
#     <link name="asparagus_5">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.066302</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.066302</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_6">
#     <static>1</static>
#     <link name="asparagus_6">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.10617</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.10617</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_7">
#     <static>1</static>
#     <link name="asparagus_7">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0636497</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0636497</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_8">
#     <static>1</static>
#     <link name="asparagus_8">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0528907</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0528907</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_9">
#     <static>1</static>
#     <link name="asparagus_9">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0455752</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0455752</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_10">
#     <static>1</static>
#     <link name="asparagus_10">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0698968</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0698968</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_11">
#     <static>1</static>
#     <link name="asparagus_11">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0750934</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0750934</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_12">
#     <static>1</static>
#     <link name="asparagus_12">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0669288</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0669288</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_13">
#     <static>1</static>
#     <link name="asparagus_13">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0469194</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0469194</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_14">
#     <static>1</static>
#     <link name="asparagus_14">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.100037</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.100037</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_15">
#     <static>1</static>
#     <link name="asparagus_15">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.103556</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.103556</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_16">
#     <static>1</static>
#     <link name="asparagus_16">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.111167</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.111167</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_17">
#     <static>1</static>
#     <link name="asparagus_17">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.11054</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.11054</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_18">
#     <static>1</static>
#     <link name="asparagus_18">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0965282</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0965282</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_19">
#     <static>1</static>
#     <link name="asparagus_19">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0256996</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0256996</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_20">
#     <static>1</static>
#     <link name="asparagus_20">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0256812</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0256812</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_21">
#     <static>1</static>
#     <link name="asparagus_21">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0284065</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0284065</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_22">
#     <static>1</static>
#     <link name="asparagus_22">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.126719</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.126719</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_23">
#     <static>1</static>
#     <link name="asparagus_23">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.144121</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.144121</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_24">
#     <static>1</static>
#     <link name="asparagus_24">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.062786</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.062786</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_25">
#     <static>1</static>
#     <link name="asparagus_25">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.060605</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.060605</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_26">
#     <static>1</static>
#     <link name="asparagus_26">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.042117</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.042117</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_27">
#     <static>1</static>
#     <link name="asparagus_27">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0806485</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0806485</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_28">
#     <static>1</static>
#     <link name="asparagus_28">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0366917</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0366917</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_29">
#     <static>1</static>
#     <link name="asparagus_29">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.081036</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.081036</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_30">
#     <static>1</static>
#     <link name="asparagus_30">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0939761</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0939761</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_31">
#     <static>1</static>
#     <link name="asparagus_31">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0658657</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0658657</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_32">
#     <static>1</static>
#     <link name="asparagus_32">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0712683</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0712683</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_33">
#     <static>1</static>
#     <link name="asparagus_33">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.078693</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.078693</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_34">
#     <static>1</static>
#     <link name="asparagus_34">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0985257</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0985257</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_35">
#     <static>1</static>
#     <link name="asparagus_35">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.011558</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.011558</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_36">
#     <static>1</static>
#     <link name="asparagus_36">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.042403</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.042403</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_37">
#     <static>1</static>
#     <link name="asparagus_37">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119814</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119814</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_38">
#     <static>1</static>
#     <link name="asparagus_38">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0854035</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0854035</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_39">
#     <static>1</static>
#     <link name="asparagus_39">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0796876</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0796876</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_40">
#     <static>1</static>
#     <link name="asparagus_40">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0435536</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0435536</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_41">
#     <static>1</static>
#     <link name="asparagus_41">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0866398</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0866398</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_42">
#     <static>1</static>
#     <link name="asparagus_42">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119309</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119309</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_43">
#     <static>1</static>
#     <link name="asparagus_43">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0687386</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0687386</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_44">
#     <static>1</static>
#     <link name="asparagus_44">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0841191</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0841191</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_45">
#     <static>1</static>
#     <link name="asparagus_45">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0443498</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0443498</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_46">
#     <static>1</static>
#     <link name="asparagus_46">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.116816</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.116816</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_47">
#     <static>1</static>
#     <link name="asparagus_47">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0148502</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0148502</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_48">
#     <static>1</static>
#     <link name="asparagus_48">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0958099</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0958099</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_49">
#     <static>1</static>
#     <link name="asparagus_49">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.00842218</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.00842218</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_50">
#     <static>1</static>
#     <link name="asparagus_50">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0684447</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0684447</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_51">
#     <static>1</static>
#     <link name="asparagus_51">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0801107</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0801107</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_52">
#     <static>1</static>
#     <link name="asparagus_52">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0931899</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0931899</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_53">
#     <static>1</static>
#     <link name="asparagus_53">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0525305</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0525305</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_54">
#     <static>1</static>
#     <link name="asparagus_54">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0772731</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0772731</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_55">
#     <static>1</static>
#     <link name="asparagus_55">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.00374806</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.00374806</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_56">
#     <static>1</static>
#     <link name="asparagus_56">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0413167</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0413167</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_57">
#     <static>1</static>
#     <link name="asparagus_57">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0972009</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0972009</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_58">
#     <static>1</static>
#     <link name="asparagus_58">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.11575</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.11575</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_59">
#     <static>1</static>
#     <link name="asparagus_59">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0196523</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0196523</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_60">
#     <static>1</static>
#     <link name="asparagus_60">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0294308</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0294308</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_61">
#     <static>1</static>
#     <link name="asparagus_61">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0736682</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0736682</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_62">
#     <static>1</static>
#     <link name="asparagus_62">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.104974</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.104974</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_63">
#     <static>1</static>
#     <link name="asparagus_63">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.172874</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.172874</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_64">
#     <static>1</static>
#     <link name="asparagus_64">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.127024</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.127024</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_65">
#     <static>1</static>
#     <link name="asparagus_65">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0278107</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0278107</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_66">
#     <static>1</static>
#     <link name="asparagus_66">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0798101</scale>
#           </mesh>
#         </geometry>
#       </visual>
# ...
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_88">
#     <static>1</static>
#     <link name="asparagus_88">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119979</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.119979</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_89">
#     <static>1</static>
#     <link name="asparagus_89">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0526281</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.08 0.08 0.0526281</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <state world_name="default">
#     <iterations>0</iterations>
#     <model name="asparagus_0">
#       <pose frame="">-4.52128 -3.80488 0 0.0719208 0.176819 1.10575</pose>
#       <link name="link">
#         <pose frame="">-4.52128 -3.80488 0 0.0719208 0.176819 1.10575</pose>
#       </link>
#     </model>
#     <model name="asparagus_1">
#       <pose frame="">-0.681404 -3.60093 0 0.0833945 -0.00468952 2.95585</pose>
#       <link name="link">
#         <pose frame="">-0.681404 -3.60093 0 0.0833945 -0.00468952 2.95585</pose>
#       </link>
#     </model>
#     <model name="asparagus_2">
#       <pose frame="">3.06526 -3.65687 0 0.0436432 0.0724529 0.696266</pose>
#       <link name="link">
#         <pose frame="">3.06526 -3.65687 0 0.0436432 0.0724529 0.696266</pose>
#       </link>
#     </model>
#     <model name="asparagus_3">
#       <pose frame="">-4.61416 -3.13832 0 0.0594138 -0.0946108 4.84092</pose>
#       <link name="link">
#         <pose frame="">-4.61416 -3.13832 0 0.0594138 -0.0946108 4.84092</pose>
#       </link>
#     </model>
#     <model name="asparagus_4">
#       <pose frame="">-0.600352 -2.88478 0 0.0550416 -0.0193464 1.66323</pose>
#       <link name="link">
#         <pose frame="">-0.600352 -2.88478 0 0.0550416 -0.0193464 1.66323</pose>
#       </link>
#     </model>
#     <model name="asparagus_5">
#       <pose frame="">3.06694 -3.08617 0 -0.0182469 -0.0163208 3.66892</pose>
#       <link name="link">
#         <pose frame="">3.06694 -3.08617 0 -0.0182469 -0.0163208 3.66892</pose>
#       </link>
#     </model>
#     <model name="asparagus_6">
#       <pose frame="">-4.35019 -2.36301 0 0.0173535 -0.0121972 5.40517</pose>
#       <link name="link">
#         <pose frame="">-4.35019 -2.36301 0 0.0173535 -0.0121972 5.40517</pose>
#       </link>
#     </model>
#     <model name="asparagus_7">
#       <pose frame="">-0.845756 -2.29373 0 0.142659 0.0536504 0.0874204</pose>
#       <link name="link">
#         <pose frame="">-0.845756 -2.29373 0 0.142659 0.0536504 0.0874204</pose>
#       </link>
#     </model>
#     <model name="asparagus_8">
#       <pose frame="">3.07934 -2.36494 0 -0.105065 0.13855 4.567</pose>
#       <link name="link">
#         <pose frame="">3.07934 -2.36494 0 -0.105065 0.13855 4.567</pose>
#       </link>
#     </model>
#     <model name="asparagus_9">
#       <pose frame="">-4.55137 -1.40114 0 -0.0420186 0.297126 5.3487</pose>
#       <link name="link">
#         <pose frame="">-4.55137 -1.40114 0 -0.0420186 0.297126 5.3487</pose>
#       </link>
#     </model>
#     <model name="asparagus_10">
#       <pose frame="">-0.897369 -1.35707 0 -0.0802612 -0.0250229 3.34555</pose>
#       <link name="link">
#         <pose frame="">-0.897369 -1.35707 0 -0.0802612 -0.0250229 3.34555</pose>
#       </link>
#     </model>
#     <model name="asparagus_11">
#       <pose frame="">3.09098 -1.57637 0 -0.0136942 -0.0207091 2.4649</pose>
#       <link name="link">
#         <pose frame="">3.09098 -1.57637 0 -0.0136942 -0.0207091 2.4649</pose>
#       </link>
#     </model>
#     <model name="asparagus_12">
#       <pose frame="">-4.39042 -0.868248 0 -0.0108424 -0.0311556 3.57876</pose>
#       <link name="link">
#         <pose frame="">-4.39042 -0.868248 0 -0.0108424 -0.0311556 3.57876</pose>
#       </link>
#     </model>
#     <model name="asparagus_13">
#       <pose frame="">-0.721173 -0.884674 0 0.013929 0.0164348 0.82488</pose>
#       <link name="link">
#         <pose frame="">-0.721173 -0.884674 0 0.013929 0.0164348 0.82488</pose>
#       </link>
#     </model>
#     <model name="asparagus_14">
#       <pose frame="">2.87871 -0.7128 0 0.121903 0.00797219 0.00182327</pose>
#       <link name="link">
#         <pose frame="">2.87871 -0.7128 0 0.121903 0.00797219 0.00182327</pose>
#       </link>
#     </model>
#     <model name="asparagus_15">
#       <pose frame="">-4.38954 -0.0349607 0 -0.00642679 -0.0873538 0.46971</pose>
#       <link name="link">
#         <pose frame="">-4.38954 -0.0349607 0 -0.00642679 -0.0873538 0.46971</pose>
#       </link>
#     </model>
#     <model name="asparagus_16">
#       <pose frame="">-0.652126 0.0685692 0 -0.0894955 -0.0220787 2.71983</pose>
#       <link name="link">
#         <pose frame="">-0.652126 0.0685692 0 -0.0894955 -0.0220787 2.71983</pose>
#       </link>
#     </model>
#     <model name="asparagus_17">
#       <pose frame="">3.0076 -0.000443882 0 -0.0338409 -0.0874487 5.08048</pose>
#       <link name="link">
#         <pose frame="">3.0076 -0.000443882 0 -0.0338409 -0.0874487 5.08048</pose>
#       </link>
#     </model>
#     <model name="asparagus_18">
#       <pose frame="">-4.3936 0.683928 0 -0.0318775 0.0726185 5.72656</pose>
#       <link name="link">
#         <pose frame="">-4.3936 0.683928 0 -0.0318775 0.0726185 5.72656</pose>
#       </link>
#     </model>
#     <model name="asparagus_19">
#       <pose frame="">-0.624588 0.851594 0 -0.0396792 0.0635954 4.56001</pose>
#       <link name="link">
#         <pose frame="">-0.624588 0.851594 0 -0.0396792 0.0635954 4.56001</pose>
#       </link>
#     </model>
#     <model name="asparagus_20">
#       <pose frame="">3.13034 0.835927 0 -0.0804676 -0.0185321 4.9299</pose>
#       <link name="link">
#         <pose frame="">3.13034 0.835927 0 -0.0804676 -0.0185321 4.9299</pose>
#       </link>
#     </model>
#     <model name="asparagus_21">
#       <pose frame="">-4.53934 1.60745 0 0.104059 -0.121952 2.20451</pose>
#       <link name="link">
#         <pose frame="">-4.53934 1.60745 0 0.104059 -0.121952 2.20451</pose>
#       </link>
#     </model>
#     <model name="asparagus_22">
#       <pose frame="">-0.873677 1.46541 0 -0.0023665 -0.11308 5.31299</pose>
#       <link name="link">
#         <pose frame="">-0.873677 1.46541 0 -0.0023665 -0.11308 5.31299</pose>
#       </link>
#     </model>
#     <model name="asparagus_23">
#       <pose frame="">3.10822 1.60423 0 0.00725495 0.113659 2.27809</pose>
#       <link name="link">
#         <pose frame="">3.10822 1.60423 0 0.00725495 0.113659 2.27809</pose>
#       </link>
#     </model>
#     <model name="asparagus_24">
#       <pose frame="">-4.53777 2.20923 0 0.0405291 -0.0111344 0.172787</pose>
#       <link name="link">
#         <pose frame="">-4.53777 2.20923 0 0.0405291 -0.0111344 0.172787</pose>
#       </link>
#     </model>
#     <model name="asparagus_25">
#       <pose frame="">-0.783199 2.22979 0 -0.0178321 -0.114755 6.0688</pose>
#       <link name="link">
#         <pose frame="">-0.783199 2.22979 0 -0.0178321 -0.114755 6.0688</pose>
#       </link>
#     </model>
#     <model name="asparagus_26">
#       <pose frame="">3.03348 2.24019 0 -0.0847051 -0.0890057 0.664344</pose>
#       <link name="link">
#         <pose frame="">3.03348 2.24019 0 -0.0847051 -0.0890057 0.664344</pose>
#       </link>
#     </model>
#     <model name="asparagus_27">
#       <pose frame="">-4.63515 2.92172 0 0.111549 -0.187952 4.32858</pose>
#       <link name="link">
#         <pose frame="">-4.63515 2.92172 0 0.111549 -0.187952 4.32858</pose>
#       </link>
#     </model>
#     <model name="asparagus_28">
#       <pose frame="">-0.773185 3.02285 0 0.24523 -0.0051004 6.06496</pose>
#       <link name="link">
#         <pose frame="">-0.773185 3.02285 0 0.24523 -0.0051004 6.06496</pose>
#       </link>
#     </model>
#     <model name="asparagus_29">
#       <pose frame="">2.88505 3.10361 0 -0.0483326 0.0188745 3.31372</pose>
#       <link name="link">
#         <pose frame="">2.88505 3.10361 0 -0.0483326 0.0188745 3.31372</pose>
#       </link>
#     </model>
#     <model name="asparagus_30">
#       <pose frame="">-3.63347 -3.83264 0 0.00806732 -0.0171865 0.456103</pose>
#       <link name="link">
#         <pose frame="">-3.63347 -3.83264 0 0.00806732 -0.0171865 0.456103</pose>
#       </link>
#     </model>
#     <model name="asparagus_31">
#       <pose frame="">-0.0309248 -3.75002 0 0.120855 0.117101 4.77021</pose>
#       <link name="link">
#         <pose frame="">-0.0309248 -3.75002 0 0.120855 0.117101 4.77021</pose>
#       </link>
#     </model>
#     <model name="asparagus_32">
#       <pose frame="">3.81083 -3.87672 0 -0.103047 0.118961 4.04802</pose>
#       <link name="link">
#         <pose frame="">3.81083 -3.87672 0 -0.103047 0.118961 4.04802</pose>
#       </link>
#     </model>
#     <model name="asparagus_33">
#       <pose frame="">-3.81623 -2.98079 0 -0.125562 0.00226494 4.87781</pose>
#       <link name="link">
#         <pose frame="">-3.81623 -2.98079 0 -0.125562 0.00226494 4.87781</pose>
#       </link>
#     </model>
#     <model name="asparagus_34">
#       <pose frame="">-0.0591639 -3.10237 0 -0.0949771 -0.0336026 5.58241</pose>
#       <link name="link">
#         <pose frame="">-0.0591639 -3.10237 0 -0.0949771 -0.0336026 5.58241</pose>
#       </link>
#     </model>
#     <model name="asparagus_35">
#       <pose frame="">3.69942 -3.00557 0 -0.230444 0.0681527 1.48461</pose>
#       <link name="link">
#         <pose frame="">3.69942 -3.00557 0 -0.230444 0.0681527 1.48461</pose>
#       </link>
#     </model>
#     <model name="asparagus_36">
#       <pose frame="">-3.88663 -2.37653 0 -0.281652 0.0291883 2.5521</pose>
#       <link name="link">
#         <pose frame="">-3.88663 -2.37653 0 -0.281652 0.0291883 2.5521</pose>
#       </link>
#     </model>
#     <model name="asparagus_37">
#       <pose frame="">0.118717 -2.19125 0 -0.069516 0.0577993 0.847161</pose>
#       <link name="link">
#         <pose frame="">0.118717 -2.19125 0 -0.069516 0.0577993 0.847161</pose>
#       </link>
#     </model>
#     <model name="asparagus_38">
#       <pose frame="">3.75295 -2.28293 0 -0.174278 0.0168699 3.14527</pose>
#       <link name="link">
#         <pose frame="">3.75295 -2.28293 0 -0.174278 0.0168699 3.14527</pose>
#       </link>
#     </model>
#     <model name="asparagus_39">
#       <pose frame="">-3.87407 -1.48404 0 -0.00386143 -0.0640303 1.92574</pose>
#       <link name="link">
#         <pose frame="">-3.87407 -1.48404 0 -0.00386143 -0.0640303 1.92574</pose>
#       </link>
#     </model>
#     <model name="asparagus_40">
#       <pose frame="">-0.066909 -1.5279 0 -0.0281969 -0.124634 0.582366</pose>
#       <link name="link">
#         <pose frame="">-0.066909 -1.5279 0 -0.0281969 -0.124634 0.582366</pose>
#       </link>
#     </model>
#     <model name="asparagus_41">
#       <pose frame="">3.71654 -1.43978 0 -0.215844 -0.137804 6.14913</pose>
#       <link name="link">
#         <pose frame="">3.71654 -1.43978 0 -0.215844 -0.137804 6.14913</pose>
#       </link>
#     </model>
#     <model name="asparagus_42">
#       <pose frame="">-3.82162 -0.688808 0 -0.00951614 0.0806551 0.989989</pose>
#       <link name="link">
#         <pose frame="">-3.82162 -0.688808 0 -0.00951614 0.0806551 0.989989</pose>
#       </link>
#     </model>
#     <model name="asparagus_43">
#       <pose frame="">-0.000170472 -0.618509 0 0.137441 0.0323205 5.55671</pose>
#       <link name="link">
#         <pose frame="">-0.000170472 -0.618509 0 0.137441 0.0323205 5.55671</pose>
#       </link>
#     </model>
#     <model name="asparagus_44">
#       <pose frame="">3.78938 -0.732291 0 0.0675421 -0.00843678 0.542398</pose>
#       <link name="link">
#         <pose frame="">3.78938 -0.732291 0 0.0675421 -0.00843678 0.542398</pose>
#       </link>
#     </model>
#     <model name="asparagus_45">
#       <pose frame="">-3.74702 0.082703 0 -0.151892 0.110115 0.0950031</pose>
#       <link name="link">
#         <pose frame="">-3.74702 0.082703 0 -0.151892 0.110115 0.0950031</pose>
#       </link>
#     </model>
#     <model name="asparagus_46">
#       <pose frame="">-0.105854 0.082267 0 0.123103 -0.070608 2.67436</pose>
#       <link name="link">
#         <pose frame="">-0.105854 0.082267 0 0.123103 -0.070608 2.67436</pose>
#       </link>
#     </model>
#     <model name="asparagus_47">
#       <pose frame="">3.82338 0.0523479 0 -0.0121805 0.0910565 4.19425</pose>
#       <link name="link">
#         <pose frame="">3.82338 0.0523479 0 -0.0121805 0.0910565 4.19425</pose>
#       </link>
#     </model>
#     <model name="asparagus_48">
#       <pose frame="">-3.76072 0.811904 0 -0.136087 -0.0368205 2.67796</pose>
#       <link name="link">
#         <pose frame="">-3.76072 0.811904 0 -0.136087 -0.0368205 2.67796</pose>
#       </link>
#     </model>
#     <model name="asparagus_49">
#       <pose frame="">-0.085299 0.707472 0 -0.0461605 0.00147335 3.95874</pose>
#       <link name="link">
#         <pose frame="">-0.085299 0.707472 0 -0.0461605 0.00147335 3.95874</pose>
#       </link>
#     </model>
#     <model name="asparagus_50">
#       <pose frame="">3.67569 0.877576 0 -0.153469 0.107028 2.65937</pose>
#       <link name="link">
#         <pose frame="">3.67569 0.877576 0 -0.153469 0.107028 2.65937</pose>
#       </link>
#     </model>
#     <model name="asparagus_51">
#       <pose frame="">-3.88376 1.40371 0 0.0994195 0.169201 1.23269</pose>
#       <link name="link">
#         <pose frame="">-3.88376 1.40371 0 0.0994195 0.169201 1.23269</pose>
#       </link>
#     </model>
#     <model name="asparagus_52">
#       <pose frame="">-0.106719 1.63644 0 0.0597861 -0.121553 5.90182</pose>
#       <link name="link">
#         <pose frame="">-0.106719 1.63644 0 0.0597861 -0.121553 5.90182</pose>
#       </link>
#     </model>
#     <model name="asparagus_53">
#       <pose frame="">3.80776 1.50616 0 -0.0571871 -0.0259861 0.84187</pose>
#       <link name="link">
#         <pose frame="">3.80776 1.50616 0 -0.0571871 -0.0259861 0.84187</pose>
#       </link>
#     </model>
#     <model name="asparagus_54">
#       <pose frame="">-3.79478 2.38305 0 0.00366046 -0.18775 5.27778</pose>
#       <link name="link">
#         <pose frame="">-3.79478 2.38305 0 0.00366046 -0.18775 5.27778</pose>
#       </link>
#     </model>
#     <model name="asparagus_55">
#       <pose frame="">-0.0301316 2.18569 0 -0.044765 -0.00311651 5.9323</pose>
#       <link name="link">
#         <pose frame="">-0.0301316 2.18569 0 -0.044765 -0.00311651 5.9323</pose>
#       </link>
#     </model>
#     <model name="asparagus_56">
#       <pose frame="">3.85497 2.12825 0 -0.140271 -0.0754649 0.93299</pose>
#       <link name="link">
#         <pose frame="">3.85497 2.12825 0 -0.140271 -0.0754649 0.93299</pose>
#       </link>
#     </model>
#     <model name="asparagus_57">
#       <pose frame="">-3.82544 2.87007 0 -0.0719088 -0.0330931 3.49192</pose>
#       <link name="link">
#         <pose frame="">-3.82544 2.87007 0 -0.0719088 -0.0330931 3.49192</pose>
#       </link>
#     </model>
#     <model name="asparagus_58">
#       <pose frame="">-0.13883 2.91529 0 -0.166342 -0.182901 3.95091</pose>
#       <link name="link">
#         <pose frame="">-0.13883 2.91529 0 -0.166342 -0.182901 3.95091</pose>
#       </link>
#     </model>
#     <model name="asparagus_59">
#       <pose frame="">3.6147 2.94971 0 0.0953272 -0.144081 6.17885</pose>
#       <link name="link">
#         <pose frame="">3.6147 2.94971 0 0.0953272 -0.144081 6.17885</pose>
#       </link>
#     </model>
#   </state>
# </world>

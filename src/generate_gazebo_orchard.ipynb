# %%
from pcg_gazebo.parsers.sdf import create_sdf_element
import numpy as np

# %%
import os
import trimesh
import matplotlib.pyplot as plt
import numpy as np
from skimage.draw import random_shapes, disk
from skimage.util import invert
from pcg_gazebo.generators import HeightmapGenerator
from pcg_gazebo.generators.biomes import Biome, WhittakerBiome

# %%
# hg = HeightmapGenerator(
#     map_size=[400, 400, 1])

# hg.reset()
# hg.add_random_layer(min_value=0, max_value=0.2)
# hg.add_perlin_noise_layer(freq=300.0, octaves=10)
# hg.add_simplex_noise_layer(freq=300.0, octaves=10)
# hg.show()

# %%
# scene = trimesh.Scene([hg.heightmap.mesh.mesh])
# scene.show()

# %%
# # Creating a biome from flat colors
# biome = Biome(n_moisture_zones=1, n_elevation_zones=4)

# biome.add_biome('bottom', color=[125, 93, 33])
# biome.add_biome('middle1', color=[168, 154, 89])
# biome.add_biome('middle2', color=[127, 59, 11])
# biome.add_biome('top', color=[100, 133, 52])

# biome.add_rule(biome='bottom', moisture_zone=0, elevation_zone=0)
# biome.add_rule(biome='middle1', moisture_zone=0, elevation_zone=1)
# biome.add_rule(biome='middle2', moisture_zone=0, elevation_zone=2)
# biome.add_rule(biome='top', moisture_zone=0, elevation_zone=3)

# # The first blending of textures happends after the first layer ("bottom" biome)
# biome.set_min_height(height=0.75, elevation_zone=1)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=1)

# biome.set_min_height(height=0.85, elevation_zone=2)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=2)

# biome.set_min_height(height=0.95, elevation_zone=3)
# biome.set_fade_dist(fade_dist=0.02, elevation_zone=3)

# %%
# fig = biome.show()

# %%
# hg.biome = biome
# model_ground = hg.as_model()
# model_ground.name = 'pcg_test_heightmap'
# model_path = model_ground.to_gazebo_model(copy_resources=True, overwrite=True)

# print('Gazebo model stored at: {}'.format(model_path))

# print('List of files in {}: {}'.format(model_path, os.listdir(model_path)))
# print('List of files in {}: {}'.format(os.path.join(model_path, 'materials', 'textures'), os.listdir(os.path.join(model_path, 'materials', 'textures'))))

# %% [markdown]
# <!-- model_ground -->

# %%
# print(model_ground.to_sdf())

# %%
# print(hg.heightmap.to_sdf())

# %%
world = create_sdf_element('world')
state = create_sdf_element('state')
state.world_name="default"

# %%
# world.add_model('pcg_test_heightmap', model_ground)

# %%
# state.add_model('pcg_test_heightmap')

# state.models[-1].pose = [0,0,0,0,0,0]
# state.models[-1].add_link('link')
# state.models[-1].links[0].pose = [0,0,0,0,0,0]

# %%
# scale = np.random.uniform(0.8,1.2)
# mud_ground = create_sdf_element('model')
# mud_ground.static = True
# mud_ground.name = "mud_ground_{}".format(i)
# mud_ground.add_link(name="mud_ground_{}".format(i))
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://Tree_1/Tree_1.dae"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# tree.links[0].self_collide = False
# tree.links[0].enable_wind = False
# tree.links[0].kinematic = False
# tree.links[0].add_visual("visual",visual)
# tree.links[0].add_collision("collision",collision)

# %%
world.add_include('include_1')
world.includes[0].uri = 'model://mud_box'

print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
# </world>

# %%
world.add_include('include_2')
world.includes[1].uri = 'model://sun'

print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
#   <include>
#     <uri>model://sun</uri>
#   </include>
# </world>

# %%
# mud_box = create_sdf_element('model')
# mud_box.static = True
# mud_box.name = "mud_box_{}".format(i)
# mud_box.add_link(name="mud_box_{}".format(i))
# scale = 10
# visual = create_sdf_element('visual')
# visual.geometry.mesh = create_sdf_element('mesh')
# visual.geometry.mesh.uri="model://mud_box"
# visual.geometry.mesh.scale=[scale, scale, scale]
# collision = create_sdf_element('collision')
# collision.geometry.mesh = create_sdf_element('mesh')
# collision.geometry.mesh.uri="model://mud_box"
# collision.geometry.mesh.scale = [scale, scale, scale]
# collision.max_contacts = 10
# asparagus.links[0].self_collide = False
# asparagus.links[0].enable_wind = False
# asparagus.links[0].kinematic = False
# asparagus.links[0].add_visual("visual",visual)
# asparagus.links[0].add_collision("collision",collision)
# world.add_model('mud_box_{}'.format(i), mud_box)

# %%
n_rows = 3
n_cols = 10
n_bushes = 3
n_trees = n_rows * n_cols * n_bushes
spacing = 0.75
bush_spacing = 3.75

# %%
cnt = 0
for row in range(int(-n_rows/2),int(n_rows/2)):
    for col in range(int(-n_cols/2),int(n_cols/2)):
        for bush in range(n_bushes):
            i = cnt
            roll = np.random.normal(0,0.1)
            pitch = np.random.normal(0,0.1)
            yaw = np.random.uniform(0,np.pi*2)
            jitter_x = np.random.uniform(-0.3,0.3)
            jitter_y = np.random.uniform(-0.3,0.3)
            state.add_model('asparagus_{}'.format(i))
            state.models[i].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,roll,pitch,yaw]
            state.models[i].add_link('link')
            state.models[i].links[0].pose = [row*spacing + jitter_x + (bush-1) * bush_spacing, col*spacing + jitter_y,0,roll,pitch,yaw]
            cnt += 1

# %%
for i in range(n_trees):
    scale = 0.1
    scale_z = np.random.uniform(0.0125,0.15)
    asparagus = create_sdf_element('model')
    asparagus.static = True
    asparagus.name = "asparagus_{}".format(i)
    asparagus.add_link(name="asparagus_{}".format(i))
    visual = create_sdf_element('visual')
    visual.geometry.mesh = create_sdf_element('mesh')
    visual.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    visual.geometry.mesh.scale=[scale, scale, scale_z]
    collision = create_sdf_element('collision')
    collision.geometry.mesh = create_sdf_element('mesh')
    collision.geometry.mesh.uri="model://Asparagus/meshes/asparagus.obj"
    collision.geometry.mesh.scale = [scale, scale, scale_z]
    collision.max_contacts = 10
    asparagus.links[0].self_collide = False
    asparagus.links[0].enable_wind = False
    asparagus.links[0].kinematic = False
    asparagus.links[0].add_visual("visual",visual)
    asparagus.links[0].add_collision("collision",collision)
    world.add_model('asparagus_{}'.format(i), asparagus)

# %%
world.add_state("default",state)

# %%
print(world)
# Out:
# <world name="default">
#   <atmosphere type="adiabatic"/>
#   <wind>
#     <linear_velocity>0 0 0</linear_velocity>
#   </wind>
#   <physics name="default_physics" default="1" type="ode">
#     <max_step_size>0.001</max_step_size>
#     <real_time_factor>1</real_time_factor>
#     <real_time_update_rate>1000</real_time_update_rate>
#   </physics>
#   <gravity>0 0 -9.8</gravity>
#   <include>
#     <uri>model://mud_box</uri>
#   </include>
#   <include>
#     <uri>model://sun</uri>
#   </include>
#   <model name="asparagus_0">
#     <static>1</static>
#     <link name="asparagus_0">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.130763</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.130763</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_1">
#     <static>1</static>
#     <link name="asparagus_1">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.131553</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.131553</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_2">
#     <static>1</static>
#     <link name="asparagus_2">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.106521</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.106521</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_3">
#     <static>1</static>
#     <link name="asparagus_3">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.125247</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.125247</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_4">
#     <static>1</static>
#     <link name="asparagus_4">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.130803</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.130803</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_5">
#     <static>1</static>
#     <link name="asparagus_5">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0715828</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0715828</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_6">
#     <static>1</static>
#     <link name="asparagus_6">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.120363</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.120363</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_7">
#     <static>1</static>
#     <link name="asparagus_7">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.104197</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.104197</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_8">
#     <static>1</static>
#     <link name="asparagus_8">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.104344</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.104344</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_9">
#     <static>1</static>
#     <link name="asparagus_9">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.149567</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.149567</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_10">
#     <static>1</static>
#     <link name="asparagus_10">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.10451</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.10451</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_11">
#     <static>1</static>
#     <link name="asparagus_11">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0664485</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0664485</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_12">
#     <static>1</static>
#     <link name="asparagus_12">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146552</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146552</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_13">
#     <static>1</static>
#     <link name="asparagus_13">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.103961</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.103961</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_14">
#     <static>1</static>
#     <link name="asparagus_14">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0633892</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0633892</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_15">
#     <static>1</static>
#     <link name="asparagus_15">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0218333</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0218333</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_16">
#     <static>1</static>
#     <link name="asparagus_16">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.140227</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.140227</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_17">
#     <static>1</static>
#     <link name="asparagus_17">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0889139</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0889139</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_18">
#     <static>1</static>
#     <link name="asparagus_18">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0919938</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0919938</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_19">
#     <static>1</static>
#     <link name="asparagus_19">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0935289</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0935289</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_20">
#     <static>1</static>
#     <link name="asparagus_20">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0972358</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0972358</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_21">
#     <static>1</static>
#     <link name="asparagus_21">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.037623</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.037623</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_22">
#     <static>1</static>
#     <link name="asparagus_22">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.034627</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.034627</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_23">
#     <static>1</static>
#     <link name="asparagus_23">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0393633</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0393633</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_24">
#     <static>1</static>
#     <link name="asparagus_24">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.112118</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.112118</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_25">
#     <static>1</static>
#     <link name="asparagus_25">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.124993</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.124993</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_26">
#     <static>1</static>
#     <link name="asparagus_26">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.138144</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.138144</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_27">
#     <static>1</static>
#     <link name="asparagus_27">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0154142</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0154142</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_28">
#     <static>1</static>
#     <link name="asparagus_28">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0385148</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0385148</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_29">
#     <static>1</static>
#     <link name="asparagus_29">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.111231</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.111231</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_30">
#     <static>1</static>
#     <link name="asparagus_30">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.027052</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.027052</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_31">
#     <static>1</static>
#     <link name="asparagus_31">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0697764</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0697764</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_32">
#     <static>1</static>
#     <link name="asparagus_32">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.142608</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.142608</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_33">
#     <static>1</static>
#     <link name="asparagus_33">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146777</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146777</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_34">
#     <static>1</static>
#     <link name="asparagus_34">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.124707</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.124707</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_35">
#     <static>1</static>
#     <link name="asparagus_35">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.11925</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.11925</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_36">
#     <static>1</static>
#     <link name="asparagus_36">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0284879</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0284879</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_37">
#     <static>1</static>
#     <link name="asparagus_37">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0364692</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0364692</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_38">
#     <static>1</static>
#     <link name="asparagus_38">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0439378</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0439378</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_39">
#     <static>1</static>
#     <link name="asparagus_39">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0454579</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0454579</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_40">
#     <static>1</static>
#     <link name="asparagus_40">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0255354</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0255354</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_41">
#     <static>1</static>
#     <link name="asparagus_41">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0753727</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0753727</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_42">
#     <static>1</static>
#     <link name="asparagus_42">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0580229</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0580229</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_43">
#     <static>1</static>
#     <link name="asparagus_43">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.101779</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.101779</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_44">
#     <static>1</static>
#     <link name="asparagus_44">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.046083</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.046083</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_45">
#     <static>1</static>
#     <link name="asparagus_45">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0774756</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0774756</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_46">
#     <static>1</static>
#     <link name="asparagus_46">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0785573</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0785573</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_47">
#     <static>1</static>
#     <link name="asparagus_47">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0967566</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0967566</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_48">
#     <static>1</static>
#     <link name="asparagus_48">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.102268</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.102268</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_49">
#     <static>1</static>
#     <link name="asparagus_49">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.101008</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.101008</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_50">
#     <static>1</static>
#     <link name="asparagus_50">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0516399</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0516399</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_51">
#     <static>1</static>
#     <link name="asparagus_51">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.097106</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.097106</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_52">
#     <static>1</static>
#     <link name="asparagus_52">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0933989</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0933989</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_53">
#     <static>1</static>
#     <link name="asparagus_53">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0396183</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0396183</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_54">
#     <static>1</static>
#     <link name="asparagus_54">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146559</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.146559</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_55">
#     <static>1</static>
#     <link name="asparagus_55">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0905475</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0905475</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_56">
#     <static>1</static>
#     <link name="asparagus_56">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.102346</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.102346</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_57">
#     <static>1</static>
#     <link name="asparagus_57">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0958949</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0958949</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_58">
#     <static>1</static>
#     <link name="asparagus_58">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0315703</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0315703</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_59">
#     <static>1</static>
#     <link name="asparagus_59">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0757057</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0757057</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_60">
#     <static>1</static>
#     <link name="asparagus_60">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0967827</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0967827</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_61">
#     <static>1</static>
#     <link name="asparagus_61">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0945275</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0945275</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_62">
#     <static>1</static>
#     <link name="asparagus_62">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0125317</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0125317</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_63">
#     <static>1</static>
#     <link name="asparagus_63">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0171134</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0171134</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_64">
#     <static>1</static>
#     <link name="asparagus_64">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0397575</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0397575</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_65">
#     <static>1</static>
#     <link name="asparagus_65">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0388938</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0388938</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_66">
#     <static>1</static>
#     <link name="asparagus_66">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.138991</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.138991</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
# ...
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0258061</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_88">
#     <static>1</static>
#     <link name="asparagus_88">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.11358</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.11358</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <model name="asparagus_89">
#     <static>1</static>
#     <link name="asparagus_89">
#       <self_collide>0</self_collide>
#       <enable_wind>0</enable_wind>
#       <kinematic>0</kinematic>
#       <visual name="visual">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0746401</scale>
#           </mesh>
#         </geometry>
#       </visual>
#       <collision name="collision">
#         <geometry>
#           <mesh>
#             <uri>model://Asparagus/meshes/asparagus.obj</uri>
#             <scale>0.1 0.1 0.0746401</scale>
#           </mesh>
#         </geometry>
#         <max_contacts>10</max_contacts>
#       </collision>
#     </link>
#   </model>
#   <state world_name="default">
#     <iterations>0</iterations>
#     <model name="asparagus_0">
#       <pose frame="">-4.55566 -3.81996 0 -0.00363802 0.0226406 5.7484</pose>
#       <link name="link">
#         <pose frame="">-4.55566 -3.81996 0 -0.00363802 0.0226406 5.7484</pose>
#       </link>
#     </model>
#     <model name="asparagus_1">
#       <pose frame="">-0.497476 -3.95298 0 0.0211401 -0.124595 4.62279</pose>
#       <link name="link">
#         <pose frame="">-0.497476 -3.95298 0 0.0211401 -0.124595 4.62279</pose>
#       </link>
#     </model>
#     <model name="asparagus_2">
#       <pose frame="">2.99604 -3.68678 0 -0.0320169 0.0344206 3.34116</pose>
#       <link name="link">
#         <pose frame="">2.99604 -3.68678 0 -0.0320169 0.0344206 3.34116</pose>
#       </link>
#     </model>
#     <model name="asparagus_3">
#       <pose frame="">-4.73492 -2.80168 0 0.083363 -0.00831568 0.0297822</pose>
#       <link name="link">
#         <pose frame="">-4.73492 -2.80168 0 0.083363 -0.00831568 0.0297822</pose>
#       </link>
#     </model>
#     <model name="asparagus_4">
#       <pose frame="">-0.929196 -3.12609 0 -0.0623515 -0.0609253 1.96354</pose>
#       <link name="link">
#         <pose frame="">-0.929196 -3.12609 0 -0.0623515 -0.0609253 1.96354</pose>
#       </link>
#     </model>
#     <model name="asparagus_5">
#       <pose frame="">3.16544 -3.12364 0 -0.0289738 0.132808 0.228984</pose>
#       <link name="link">
#         <pose frame="">3.16544 -3.12364 0 -0.0289738 0.132808 0.228984</pose>
#       </link>
#     </model>
#     <model name="asparagus_6">
#       <pose frame="">-4.2099 -2.30617 0 -0.093677 0.0701674 1.35985</pose>
#       <link name="link">
#         <pose frame="">-4.2099 -2.30617 0 -0.093677 0.0701674 1.35985</pose>
#       </link>
#     </model>
#     <model name="asparagus_7">
#       <pose frame="">-0.491812 -2.47429 0 0.03147 0.145058 0.695771</pose>
#       <link name="link">
#         <pose frame="">-0.491812 -2.47429 0 0.03147 0.145058 0.695771</pose>
#       </link>
#     </model>
#     <model name="asparagus_8">
#       <pose frame="">2.83401 -2.50416 0 -0.129815 0.0117151 4.446</pose>
#       <link name="link">
#         <pose frame="">2.83401 -2.50416 0 -0.129815 0.0117151 4.446</pose>
#       </link>
#     </model>
#     <model name="asparagus_9">
#       <pose frame="">-4.54822 -1.59891 0 0.00568186 0.0359459 5.78668</pose>
#       <link name="link">
#         <pose frame="">-4.54822 -1.59891 0 0.00568186 0.0359459 5.78668</pose>
#       </link>
#     </model>
#     <model name="asparagus_10">
#       <pose frame="">-0.819384 -1.26605 0 -0.0760961 -0.0798561 0.769111</pose>
#       <link name="link">
#         <pose frame="">-0.819384 -1.26605 0 -0.0760961 -0.0798561 0.769111</pose>
#       </link>
#     </model>
#     <model name="asparagus_11">
#       <pose frame="">3.12159 -1.23734 0 0.0779897 -0.00969466 2.52316</pose>
#       <link name="link">
#         <pose frame="">3.12159 -1.23734 0 0.0779897 -0.00969466 2.52316</pose>
#       </link>
#     </model>
#     <model name="asparagus_12">
#       <pose frame="">-4.41647 -0.969195 0 -0.143933 -0.0476129 4.42504</pose>
#       <link name="link">
#         <pose frame="">-4.41647 -0.969195 0 -0.143933 -0.0476129 4.42504</pose>
#       </link>
#     </model>
#     <model name="asparagus_13">
#       <pose frame="">-0.664704 -0.969321 0 0.100381 -0.190427 4.97484</pose>
#       <link name="link">
#         <pose frame="">-0.664704 -0.969321 0 0.100381 -0.190427 4.97484</pose>
#       </link>
#     </model>
#     <model name="asparagus_14">
#       <pose frame="">2.96211 -0.874852 0 0.201708 -0.0136722 4.98236</pose>
#       <link name="link">
#         <pose frame="">2.96211 -0.874852 0 0.201708 -0.0136722 4.98236</pose>
#       </link>
#     </model>
#     <model name="asparagus_15">
#       <pose frame="">-4.60237 0.177819 0 0.0164243 -0.055717 3.76871</pose>
#       <link name="link">
#         <pose frame="">-4.60237 0.177819 0 0.0164243 -0.055717 3.76871</pose>
#       </link>
#     </model>
#     <model name="asparagus_16">
#       <pose frame="">-0.504387 -0.0143066 0 0.054237 -0.0222012 0.315871</pose>
#       <link name="link">
#         <pose frame="">-0.504387 -0.0143066 0 0.054237 -0.0222012 0.315871</pose>
#       </link>
#     </model>
#     <model name="asparagus_17">
#       <pose frame="">2.88041 0.222823 0 -0.0696794 0.0471685 5.13248</pose>
#       <link name="link">
#         <pose frame="">2.88041 0.222823 0 -0.0696794 0.0471685 5.13248</pose>
#       </link>
#     </model>
#     <model name="asparagus_18">
#       <pose frame="">-4.55769 0.542222 0 0.16976 0.062711 3.10043</pose>
#       <link name="link">
#         <pose frame="">-4.55769 0.542222 0 0.16976 0.062711 3.10043</pose>
#       </link>
#     </model>
#     <model name="asparagus_19">
#       <pose frame="">-0.983996 0.679605 0 0.0582427 -0.0885542 3.87482</pose>
#       <link name="link">
#         <pose frame="">-0.983996 0.679605 0 0.0582427 -0.0885542 3.87482</pose>
#       </link>
#     </model>
#     <model name="asparagus_20">
#       <pose frame="">2.82993 0.565779 0 0.0929229 0.0554801 4.50706</pose>
#       <link name="link">
#         <pose frame="">2.82993 0.565779 0 0.0929229 0.0554801 4.50706</pose>
#       </link>
#     </model>
#     <model name="asparagus_21">
#       <pose frame="">-4.5267 1.75316 0 0.0626473 0.0288593 0.367142</pose>
#       <link name="link">
#         <pose frame="">-4.5267 1.75316 0 0.0626473 0.0288593 0.367142</pose>
#       </link>
#     </model>
#     <model name="asparagus_22">
#       <pose frame="">-0.460005 1.79035 0 0.0373007 0.0179083 3.34519</pose>
#       <link name="link">
#         <pose frame="">-0.460005 1.79035 0 0.0373007 0.0179083 3.34519</pose>
#       </link>
#     </model>
#     <model name="asparagus_23">
#       <pose frame="">2.89586 1.49089 0 0.0586128 0.124736 2.13245</pose>
#       <link name="link">
#         <pose frame="">2.89586 1.49089 0 0.0586128 0.124736 2.13245</pose>
#       </link>
#     </model>
#     <model name="asparagus_24">
#       <pose frame="">-4.79747 2.38544 0 -0.0832164 -0.188185 4.7492</pose>
#       <link name="link">
#         <pose frame="">-4.79747 2.38544 0 -0.0832164 -0.188185 4.7492</pose>
#       </link>
#     </model>
#     <model name="asparagus_25">
#       <pose frame="">-0.956922 2.2389 0 -0.0966714 0.109211 5.64817</pose>
#       <link name="link">
#         <pose frame="">-0.956922 2.2389 0 -0.0966714 0.109211 5.64817</pose>
#       </link>
#     </model>
#     <model name="asparagus_26">
#       <pose frame="">2.92266 2.1233 0 0.115208 -0.112924 0.661461</pose>
#       <link name="link">
#         <pose frame="">2.92266 2.1233 0 0.115208 -0.112924 0.661461</pose>
#       </link>
#     </model>
#     <model name="asparagus_27">
#       <pose frame="">-4.50228 3.10265 0 0.164089 0.0452655 3.62943</pose>
#       <link name="link">
#         <pose frame="">-4.50228 3.10265 0 0.164089 0.0452655 3.62943</pose>
#       </link>
#     </model>
#     <model name="asparagus_28">
#       <pose frame="">-0.953296 2.8209 0 0.123928 -0.0820117 6.07523</pose>
#       <link name="link">
#         <pose frame="">-0.953296 2.8209 0 0.123928 -0.0820117 6.07523</pose>
#       </link>
#     </model>
#     <model name="asparagus_29">
#       <pose frame="">2.74338 3.25169 0 -0.0626698 0.0757912 3.59847</pose>
#       <link name="link">
#         <pose frame="">2.74338 3.25169 0 -0.0626698 0.0757912 3.59847</pose>
#       </link>
#     </model>
#     <model name="asparagus_30">
#       <pose frame="">-3.60491 -3.73986 0 -0.0677644 -0.119243 0.648141</pose>
#       <link name="link">
#         <pose frame="">-3.60491 -3.73986 0 -0.0677644 -0.119243 0.648141</pose>
#       </link>
#     </model>
#     <model name="asparagus_31">
#       <pose frame="">0.0149243 -3.63475 0 0.0437896 0.141224 5.83797</pose>
#       <link name="link">
#         <pose frame="">0.0149243 -3.63475 0 0.0437896 0.141224 5.83797</pose>
#       </link>
#     </model>
#     <model name="asparagus_32">
#       <pose frame="">3.63552 -3.71742 0 0.0869561 0.0644211 4.29733</pose>
#       <link name="link">
#         <pose frame="">3.63552 -3.71742 0 0.0869561 0.0644211 4.29733</pose>
#       </link>
#     </model>
#     <model name="asparagus_33">
#       <pose frame="">-3.6563 -2.87467 0 -0.047641 0.0150266 4.04765</pose>
#       <link name="link">
#         <pose frame="">-3.6563 -2.87467 0 -0.047641 0.0150266 4.04765</pose>
#       </link>
#     </model>
#     <model name="asparagus_34">
#       <pose frame="">-0.240303 -2.95356 0 0.0105755 -0.030686 5.1865</pose>
#       <link name="link">
#         <pose frame="">-0.240303 -2.95356 0 0.0105755 -0.030686 5.1865</pose>
#       </link>
#     </model>
#     <model name="asparagus_35">
#       <pose frame="">3.96113 -3.21968 0 0.0477696 0.0466436 3.59787</pose>
#       <link name="link">
#         <pose frame="">3.96113 -3.21968 0 0.0477696 0.0466436 3.59787</pose>
#       </link>
#     </model>
#     <model name="asparagus_36">
#       <pose frame="">-3.74166 -2.07013 0 0.059262 -0.0827278 4.95613</pose>
#       <link name="link">
#         <pose frame="">-3.74166 -2.07013 0 0.059262 -0.0827278 4.95613</pose>
#       </link>
#     </model>
#     <model name="asparagus_37">
#       <pose frame="">-0.135826 -1.97124 0 0.139389 -0.277137 1.10955</pose>
#       <link name="link">
#         <pose frame="">-0.135826 -1.97124 0 0.139389 -0.277137 1.10955</pose>
#       </link>
#     </model>
#     <model name="asparagus_38">
#       <pose frame="">3.941 -2.30342 0 0.0253436 -0.179391 5.14078</pose>
#       <link name="link">
#         <pose frame="">3.941 -2.30342 0 0.0253436 -0.179391 5.14078</pose>
#       </link>
#     </model>
#     <model name="asparagus_39">
#       <pose frame="">-3.91974 -1.67924 0 -0.161066 -0.0300974 1.84983</pose>
#       <link name="link">
#         <pose frame="">-3.91974 -1.67924 0 -0.161066 -0.0300974 1.84983</pose>
#       </link>
#     </model>
#     <model name="asparagus_40">
#       <pose frame="">-0.260847 -1.59805 0 0.0385496 -0.0259707 2.73143</pose>
#       <link name="link">
#         <pose frame="">-0.260847 -1.59805 0 0.0385496 -0.0259707 2.73143</pose>
#       </link>
#     </model>
#     <model name="asparagus_41">
#       <pose frame="">3.62982 -1.41569 0 0.00177596 -0.216928 1.05526</pose>
#       <link name="link">
#         <pose frame="">3.62982 -1.41569 0 0.00177596 -0.216928 1.05526</pose>
#       </link>
#     </model>
#     <model name="asparagus_42">
#       <pose frame="">-3.88762 -0.78786 0 0.0192141 0.0231957 0.10979</pose>
#       <link name="link">
#         <pose frame="">-3.88762 -0.78786 0 0.0192141 0.0231957 0.10979</pose>
#       </link>
#     </model>
#     <model name="asparagus_43">
#       <pose frame="">-0.101202 -0.956011 0 0.0620776 0.00959229 1.43173</pose>
#       <link name="link">
#         <pose frame="">-0.101202 -0.956011 0 0.0620776 0.00959229 1.43173</pose>
#       </link>
#     </model>
#     <model name="asparagus_44">
#       <pose frame="">3.95521 -0.63047 0 -0.0986688 -0.177307 6.27563</pose>
#       <link name="link">
#         <pose frame="">3.95521 -0.63047 0 -0.0986688 -0.177307 6.27563</pose>
#       </link>
#     </model>
#     <model name="asparagus_45">
#       <pose frame="">-3.85408 0.075551 0 -0.0842508 -0.185324 1.21555</pose>
#       <link name="link">
#         <pose frame="">-3.85408 0.075551 0 -0.0842508 -0.185324 1.21555</pose>
#       </link>
#     </model>
#     <model name="asparagus_46">
#       <pose frame="">0.0925056 -0.286856 0 -0.136519 0.0299496 3.35381</pose>
#       <link name="link">
#         <pose frame="">0.0925056 -0.286856 0 -0.136519 0.0299496 3.35381</pose>
#       </link>
#     </model>
#     <model name="asparagus_47">
#       <pose frame="">3.56071 0.0971598 0 -0.156539 -0.101435 2.42294</pose>
#       <link name="link">
#         <pose frame="">3.56071 0.0971598 0 -0.156539 -0.101435 2.42294</pose>
#       </link>
#     </model>
#     <model name="asparagus_48">
#       <pose frame="">-3.83364 0.51713 0 0.111707 0.128144 2.1688</pose>
#       <link name="link">
#         <pose frame="">-3.83364 0.51713 0 0.111707 0.128144 2.1688</pose>
#       </link>
#     </model>
#     <model name="asparagus_49">
#       <pose frame="">0.267075 0.744023 0 0.0279355 -0.0400351 4.93302</pose>
#       <link name="link">
#         <pose frame="">0.267075 0.744023 0 0.0279355 -0.0400351 4.93302</pose>
#       </link>
#     </model>
#     <model name="asparagus_50">
#       <pose frame="">3.56404 0.788042 0 0.00850748 -0.136465 2.30914</pose>
#       <link name="link">
#         <pose frame="">3.56404 0.788042 0 0.00850748 -0.136465 2.30914</pose>
#       </link>
#     </model>
#     <model name="asparagus_51">
#       <pose frame="">-3.63018 1.38124 0 -0.00638501 0.0655202 0.168333</pose>
#       <link name="link">
#         <pose frame="">-3.63018 1.38124 0 -0.00638501 0.0655202 0.168333</pose>
#       </link>
#     </model>
#     <model name="asparagus_52">
#       <pose frame="">0.0837326 1.77018 0 -0.0244756 0.0564278 5.11377</pose>
#       <link name="link">
#         <pose frame="">0.0837326 1.77018 0 -0.0244756 0.0564278 5.11377</pose>
#       </link>
#     </model>
#     <model name="asparagus_53">
#       <pose frame="">3.75957 1.6563 0 0.00258154 -0.17641 6.28261</pose>
#       <link name="link">
#         <pose frame="">3.75957 1.6563 0 0.00258154 -0.17641 6.28261</pose>
#       </link>
#     </model>
#     <model name="asparagus_54">
#       <pose frame="">-3.90836 2.01011 0 0.0490195 -0.0839855 4.79255</pose>
#       <link name="link">
#         <pose frame="">-3.90836 2.01011 0 0.0490195 -0.0839855 4.79255</pose>
#       </link>
#     </model>
#     <model name="asparagus_55">
#       <pose frame="">-0.27866 2.54358 0 -0.0144959 0.0579696 4.50391</pose>
#       <link name="link">
#         <pose frame="">-0.27866 2.54358 0 -0.0144959 0.0579696 4.50391</pose>
#       </link>
#     </model>
#     <model name="asparagus_56">
#       <pose frame="">3.55864 2.01802 0 -0.0802002 0.11635 0.740475</pose>
#       <link name="link">
#         <pose frame="">3.55864 2.01802 0 -0.0802002 0.11635 0.740475</pose>
#       </link>
#     </model>
#     <model name="asparagus_57">
#       <pose frame="">-3.82567 3.0777 0 -0.019512 0.0589581 4.049</pose>
#       <link name="link">
#         <pose frame="">-3.82567 3.0777 0 -0.019512 0.0589581 4.049</pose>
#       </link>
#     </model>
#     <model name="asparagus_58">
#       <pose frame="">-0.234752 3.05469 0 0.0206821 0.141004 1.28475</pose>
#       <link name="link">
#         <pose frame="">-0.234752 3.05469 0 0.0206821 0.141004 1.28475</pose>
#       </link>
#     </model>
#     <model name="asparagus_59">
#       <pose frame="">3.49591 2.78391 0 -0.0460549 -0.0158595 3.72307</pose>
#       <link name="link">
#         <pose frame="">3.49591 2.78391 0 -0.0460549 -0.0158595 3.72307</pose>
#       </link>
#     </model>
#   </state>
# </world>
